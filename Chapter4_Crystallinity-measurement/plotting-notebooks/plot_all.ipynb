# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import os
import sys
import time

# %%
# figure style
plt.style.use('seaborn-v0_8-colorblind')
plt.style.use('../../../../thesis.mplstyle')

# Figure sizes
cmToInch = 1/2.54
text_width = 14.2  # cm
base_height = 5.  # cm
dpi = 400
format = 'pdf'

# %%
# # Colour reference
# colour = plt.rcParams['axes.prop_cycle'].by_key()['color']

# fig, ax = plt.subplots(figsize=(5, 4))  # Adjust figure size as needed
# for i, c in enumerate(colour):
#     ax.bar(i, 1, color=c)

# ax.set_xticks(range(len(colour)))
# ax.set_xticklabels([f'C{i}' for i in range(len(colour))])  # Optional: Label the bars
# ax.set_yticks([])  # Hide y-axis ticks

# plt.show()

# %%
# Sample ID refrence
# sample_ids = {
#     '500907': 'PEEKa',
#     '501023': 'PEEKb',
#     '501024': 'PEEKc',
#     'HDPE': 'HDPE',
# }

# %% [markdown]
# # XRD spectrum at room tempearture

# %%
from figure_XRD_spectrum_roomTemp import plot_XRD_spectrum_roomTemp

width = text_width * cmToInch
height = 2.3* base_height * cmToInch

plot_XRD_spectrum_roomTemp(
    file_path="../data/XRD_results.xlsx",
    width=width, 
    height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_legend=True, display_fig=True, save_fig=True, 
)
# Out:
# Overview data:
#        Filename Polymer_Type  Crystallinity_percent  R_squared      RMSE
# 0    500907.csv         PEEK                   0.36     0.9997  0.005648
# 1  500907_2.csv         PEEK                   0.39     0.9998  0.004591
# 2    501023.csv         PEEK                  17.25     0.9994  0.005586
# 3  501023_2.csv         PEEK                  14.54     0.9991  0.006023
# 4  501023_3.csv         PEEK                  14.70     0.9984  0.008117
#
# Available sheets: ['500907', '500907_2', '501023', '501023_2', '501023_3', '501023_4', '501024', '501024_2', 'HDPE', 'HDPE_2', 'HDPE_3', 'HDPE_4', 'Overview']
# Sample groups: {'HDPE': ['HDPE', 'HDPE_2', 'HDPE_3', 'HDPE_4'], '500907': ['500907', '500907_2'], '501023': ['501023', '501023_2', '501023_3', '501023_4'], '501024': ['501024', '501024_2']}
# Plot successfully exported to ../figures\fig_XRD_RT_specturm.pdf

# %% [markdown]
# # DSC spectra

# %%
from figure_DSC_spectrum_roomTemp import plot_DSC_spectrum_roomTemp_1st_cycle

width = text_width * cmToInch
height = 2.3* base_height * cmToInch

plot_DSC_spectrum_roomTemp_1st_cycle(
    file_path="../data/DSC_results.xlsx",
    width=width, height=height,
    save_fig=True, display_fig=True,
)
# Out:
# Overview data:
#      sample  cycle  melt enthalpy / J g^-1  crystallisation enthalpy / J g^-1  \
# 0  500907_1      1               48.462388                         -13.826475
# 1  500907_1      2               40.137647                          -0.314434
# 2  500907_1      3               36.508924                           0.339013
# 3  500907_2      1               47.184006                         -19.231306
# 4  500907_2      2               33.197172                          -1.025549
#
#    net melt enthalpy / J g^-1  CF / g g^-1
# 0                   34.635913     0.266430
# 1                   39.823213     0.306332
# 2                   36.847937     0.283446
# 3                   27.952700     0.215021
# 4                   32.171623     0.247474
#
# ...

# %%
from figure_DSC_spectrum_roomTemp import plot_DSC_spectrum_roomTemp_2nd_cycle

width = text_width * cmToInch
height = 2.3* base_height * cmToInch

plot_DSC_spectrum_roomTemp_2nd_cycle(
    file_path="../data/DSC_results.xlsx",
    width=width, height=height,
    save_fig=True, display_fig=True,
)
# Out:
# Overview data:
#      sample  cycle  melt enthalpy / J g^-1  crystallisation enthalpy / J g^-1  \
# 0  500907_1      1               48.462388                         -13.826475
# 1  500907_1      2               40.137647                          -0.314434
# 2  500907_1      3               36.508924                           0.339013
# 3  500907_2      1               47.184006                         -19.231306
# 4  500907_2      2               33.197172                          -1.025549
#
#    net melt enthalpy / J g^-1  CF / g g^-1
# 0                   34.635913     0.266430
# 1                   39.823213     0.306332
# 2                   36.847937     0.283446
# 3                   27.952700     0.215021
# 4                   32.171623     0.247474
#
# ...

# %%
from figure_DSC_spectrum_roomTemp import plot_DSC_spectrum_roomTemp_3rd_cycle

width = text_width * cmToInch
height = 2.3* base_height * cmToInch

plot_DSC_spectrum_roomTemp_3rd_cycle(
    file_path="../data/DSC_results.xlsx",
    width=width, height=height,
    save_fig=True, display_fig=True,
)
# Out:
# Overview data:
#      sample  cycle  melt enthalpy / J g^-1  crystallisation enthalpy / J g^-1  \
# 0  500907_1      1               48.462388                         -13.826475
# 1  500907_1      2               40.137647                          -0.314434
# 2  500907_1      3               36.508924                           0.339013
# 3  500907_2      1               47.184006                         -19.231306
# 4  500907_2      2               33.197172                          -1.025549
#
#    net melt enthalpy / J g^-1  CF / g g^-1
# 0                   34.635913     0.266430
# 1                   39.823213     0.306332
# 2                   36.847937     0.283446
# 3                   27.952700     0.215021
# 4                   32.171623     0.247474
#
# ...

# %% [markdown]
# # Compare DSC and XRD results at room temperature

# %%
from plot_comparison_xrd_dsc import plot_comparison_xrd_dsc_1st_cycle_roomTemp

wh_ratio = 4/3
width = 0.7 * text_width * cmToInch
height = width / wh_ratio

plot_comparison_xrd_dsc_1st_cycle_roomTemp(
    dsc_file_path="../data/DSC_results.xlsx",
    xrd_file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_crystallinity_comparison_XRD_DSC_RT.pdf

# %%
# from plot_comparison_xrd_dsc import plot_comparison_xrd_dsc_2nd_cycle_roomTemp

# wh_ratio = 4/3
# width = 0.7 * text_width * cmToInch
# height = width / wh_ratio

# plot_comparison_xrd_dsc_2nd_cycle_roomTemp(
#     dsc_file_path="../data/DSC_results.xlsx",
#     xrd_file_path="../data/XRD_results.xlsx",
#     width=width, height=height,
#     display_fig=True, save_fig=True,
# )
# Out:
# Plot successfully exported to ../figures\fig_crystallinity_comparison_XRD_DSC_RT.pdf

# %% [markdown]
# # XRD in-situ heating spectrum

# %%
from figure_XRD_spectrum_heated import plot_XRD_spectrum_heated_hdpe

width = text_width * cmToInch
height = 2.7 * base_height * cmToInch

plot_XRD_spectrum_heated_hdpe(
    file_path="../data/XRD_heated_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.5,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_heated_HDPE.pdf

# %%
from figure_XRD_spectrum_heated import plot_XRD_spectrum_heated_peek

# Usage
width = text_width * cmToInch
height = 2.7 * base_height * cmToInch
plot_XRD_spectrum_heated_peek(
    file_path="../data/XRD_heated_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.5,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_heated_PEEKa.pdf

# %% [markdown]
# # Compare XRD in-situ heating crystallinity

# %%
from figure_XRD_heated import plot_crystallinity_from_excel

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_crystallinity_from_excel('../data/XRD_heated_results.xlsx',
                              width=width, height=height,
                              display_fig=True, save_fig=True, 
                              )
# Out:
# Plot successfully exported to ../figures\fig_crystalliinity_XRD_heated.pdf

# %% [markdown]
# # Individual XRD fit (room temperature)

# %%
from figure_XRD_fitted_spectrum_roomTemp import plot_XRD_fitted_spectrum_hdpe

# Usage
width = text_width * cmToInch
height = 2.3* base_height * cmToInch
plot_XRD_fitted_spectrum_hdpe(
    file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_RT_fit_HDPE.pdf

# %%
from figure_XRD_fitted_spectrum_roomTemp import plot_XRD_fitted_spectrum_peeka

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch
plot_XRD_fitted_spectrum_peeka(
    file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_RT_fit_PEEKa.pdf

# %%
from figure_XRD_fitted_spectrum_roomTemp import plot_XRD_fitted_spectrum_peekb

width = text_width * cmToInch
height = 2.3 * base_height * cmToInch
plot_XRD_fitted_spectrum_peekb(
    file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_RT_fit_PEEKb.pdf

# %%
from figure_XRD_fitted_spectrum_roomTemp import plot_XRD_fitted_spectrum_peekc

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch
plot_XRD_fitted_spectrum_peekc(
    file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_RT_fit_PEEKc.pdf

# %% [markdown]
# # Invidual XRD fit (heated)

# %%
from figure_XRD_fitted_spectrum_heated import plot_XRD_heated_fitted_spectrum_hdpe

width = text_width * cmToInch
height = 4.* base_height * cmToInch

plot_XRD_heated_fitted_spectrum_hdpe(
    file_path="../data/XRD_heated_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_heated_fit_HDPE.pdf

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os


from figure_XRD_fitted_spectrum_heated import plot_XRD_heated_fitted_spectrum_peeka

width = text_width * cmToInch
height = 4.* base_height * cmToInch

plot_XRD_heated_fitted_spectrum_peeka(
    file_path="../data/XRD_heated_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.5,
    display_fig=True, save_fig=True, 
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_heated_fit_PEEKa.pdf

# %% [markdown]
# # Individual DSC fit (room temperature) - 1st cycle

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_1st_cycle_hdpe

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_1st_cycle_hdpe(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_HDPE_1st_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_1st_cycle_peeka

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_1st_cycle_peeka(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=True,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKa_1st_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_1st_cycle_peekb

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_1st_cycle_peekb(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKb_1st_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_1st_cycle_peekc

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_1st_cycle_peekc(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=True,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKc_1st_cycle.pdf

# %% [markdown]
# # Individual DSC fit (room temperature) - 2nd cycle

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_2nd_cycle_hdpe

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_2nd_cycle_hdpe(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_HDPE_2nd_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_2nd_cycle_peeka

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_2nd_cycle_peeka(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKa_2nd_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_2nd_cycle_peekb

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_2nd_cycle_peekb(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKb_2nd_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_2nd_cycle_peekc

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_2nd_cycle_peekc(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKc_2nd_cycle.pdf

# %% [markdown]
# # Individual DSC fit (room temperature) - 3rd cycle

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_3rd_cycle_hdpe

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_3rd_cycle_hdpe(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_HDPE_3rd_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_3rd_cycle_peeka

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_3rd_cycle_peeka(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKa_3rd_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_3rd_cycle_peekb

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_3rd_cycle_peekb(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKb_3rd_cycle.pdf

# %%
from figure_DSC_fitted_spectrum_roomTemp import plot_DSC_spectrum_fit_roomTemp_3rd_cycle_peekc

width = text_width * cmToInch
height = 1.2 * base_height * cmToInch

plot_DSC_spectrum_fit_roomTemp_3rd_cycle_peekc(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=False,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_RT_spectrum_fit_PEEKc_3rd_cycle.pdf

# %% [markdown]
# # Sample XRD fit

# %%
from figure_sample_fitted_spectrum import plot_XRD_fitted_spectrum_sample

# Usage
width = text_width * cmToInch
height = 2.3* base_height * cmToInch

plot_XRD_fitted_spectrum_sample(
    file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.25,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_RT_fit_samples.pdf

# %% [markdown]
# # Sample DSC fit (1st cycle)

# %%
from figure_sample_fitted_spectrum import plot_DSC_spectrum_fit_roomTemp_1st_cycle_sample

# Usage
width = text_width * cmToInch
height = 2.3* base_height * cmToInch
plot_DSC_spectrum_fit_roomTemp_1st_cycle_sample(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=True,
    width=width, height=height,
    display_fig=True, save_fig=False,
)

# %% [markdown]
# # Demonstration of XRD method

# %%
from figure_method_demonstration import plot_XRD_fitted_spectrum_method_demonstration

# Usage
wh_ratio = 4/3
width = 0.7 * text_width * cmToInch
height = width / wh_ratio

plot_XRD_fitted_spectrum_method_demonstration(
    file_path="../data/XRD_results.xlsx",
    width=width, height=height,
    x_lo=10, x_up=40, y_up=1.2,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_XRD_method_demonstration.pdf

# %% [markdown]
# # Demonstration of DSC method

# %%
from figure_method_demonstration import plot_DSC_fitted_spectrum_method_demonstration

# Usage
wh_ratio = 4/3
width = 0.7 * text_width * cmToInch
height = width / wh_ratio

plot_DSC_fitted_spectrum_method_demonstration(
    file_path="../data/DSC_results.xlsx",
    shade_melt=True, shade_crys=True,
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Plot successfully exported to ../figures\fig_DSC_method_demonstration.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import os
import sys
import time

# %%
# figure style
plt.style.use('seaborn-v0_8-colorblind')
plt.style.use('../../../../thesis.mplstyle')

# Figure sizes
cmToInch = 1/2.54
text_width = 14.2  # cm
base_height = 5.  # cm
dpi = 400
format = 'pdf'

# %%
# # Colour reference
# colour = plt.rcParams['axes.prop_cycle'].by_key()['color']

# fig, ax = plt.subplots(figsize=(5, 4))  # Adjust figure size as needed
# for i, c in enumerate(colour):
#     ax.bar(i, 1, color=c)

# ax.set_xticks(range(len(colour)))
# ax.set_xticklabels([f'C{i}' for i in range(len(colour))])  # Optional: Label the bars
# ax.set_yticks([])  # Hide y-axis ticks

# plt.show()

# %% [markdown]
# # Plot example breakthrough and pressure-step flux

# %%
from figure_example_flux import plot_example_flux_curves

# Usage
width = text_width * cmToInch
height = 2.5 * base_height * cmToInch

plot_example_flux_curves(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_example_flux_curves.pdf.

# %% [markdown]
# # Plot explanation for time lag

# %%
from figure_timelag_explanation import plot_timelag_explanation

width = 0.7*text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_timelag_explanation(
    width=width, height=height,
    display_fig=True, 
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_timelag_explanation.pdf

# %% [markdown]
# # Plot permeability

# %%
from figure_permeability import plot_permeability

# Usage
width = text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_permeability(
    file_path='../data/steady_state_results.xlsx',
    height=height, width=width,
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_permeability.pdf.

# %% [markdown]
# # Plot solubility from FVT

# %%
from figure_solubility_fvt import plot_solubility_fvt

df = pd.read_excel('../data/FVT/fvt_all_results.xlsx')

width = text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_solubility_fvt(
    file_path='../data/FVT/fvt_all_results.xlsx',
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_solubility_fvt.pdf

# %% [markdown]
# # Plot raw breakthrough permeation data

# %%
from figure_raw_flux import plot_raw_flux_hdpe

width = text_width * cmToInch
height = 4.7* base_height * cmToInch

plot_raw_flux_hdpe(
    data_folder_path='../data/FVT',
    x_lo=0., y_lo=0.,
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_raw_flux_HDPE.pdf

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from figure_raw_flux import plot_raw_flux_peeka

width = text_width * cmToInch
height = 1.9* base_height * cmToInch

plot_raw_flux_peeka(
    data_folder_path='../data/FVT',
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_raw_flux_peeka.pdf

# %% [markdown]
# # Plot diffusivities from time lag

# %%
from figure_timelag_diffusivity import plot_timelag_diffusivity

# Usage
width = text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_timelag_diffusivity(
    file_path='../data/timelag/timelag_all_results.csv',
    height=height, width=width,
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_timelag_diffusivity.pdf.

# %% [markdown]
# # Plot time lag fit

# %%
from figure_timelag_fit import plot_timelag_flux_fit_hdpe

width = text_width * cmToInch
height = 4.7* base_height * cmToInch

plot_timelag_flux_fit_hdpe(
    data_folder_path='../data/timelag',
    width=width, height=height,
    x_lo=0., y_lo=0.,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_timelag_flux_fit_hdpe.pdf

# %%
from figure_timelag_fit import plot_timelag_flux_fit_peeka

width = text_width * cmToInch
height = 1.9 * base_height * cmToInch

plot_timelag_flux_fit_peeka(
    data_folder_path='../data/timelag',
    width=width, height=height,
    x_lo=0., y_lo=0.,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_timelag_flux_fit_peeka.pdf

# %% [markdown]
# # Plot diffusivities from FVT

# %%
from figure_fvt_diffusivity import plot_fvt_Dprime

# Usage
width = text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_fvt_Dprime(
    file_path='../data/fvt/fvt_all_results.xlsx',
    height=height, width=width,
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_fvt_Dprime.pdf.

# %%
from figure_fvt_diffusivity import plot_fvt_DT0

# Usage
width = text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_fvt_DT0(
    file_path='../data/fvt/fvt_all_results.xlsx',
    height=height, width=width,
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_fvt_DT0.pdf.

# %% [markdown]
# # Plot FVT fit

# %%
from figure_fvt_fit import plot_fvt_flux_fit_hdpe

width = text_width * cmToInch
height = 4.7* base_height * cmToInch

plot_fvt_flux_fit_hdpe(
    data_folder_path='../data/FVT',
    width=width, height=height, 
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_fvt_flux_fit_hdpe.pdf

# %%
from figure_fvt_fit import plot_fvt_flux_fit_peeka

width = text_width * cmToInch
height = 1.9 * base_height * cmToInch

plot_fvt_flux_fit_peeka(
    data_folder_path='../data/FVT',
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_fvt_flux_fit_peeka.pdf

# %% [markdown]
# # Plot raw pressure-step data

# %%
from figure_pressure_step_raw import plot_pressure_step_raw

width = text_width * cmToInch
height = 4.5 * base_height * cmToInch

plot_pressure_step_raw(
    data_folder_path='../data/multi-step',
    width=width, height=height,
    symbol='None', markersize=2, linestyle='solid', linewidth=1,
    x_lo=0., y_lo=0.,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_pressure_step_raw.pdf

# %% [markdown]
# # Plot pressure-step fit

# %%
from figure_pressure_step_fit import plot_pressure_step_fit

width = text_width * cmToInch
height = 2.5 * base_height * cmToInch

plot_pressure_step_fit(
    data_folder_path='../data/multi-step',
    width=width, height=height,
    x_lo=0., y_lo=0., x_up=200e3, y_up=1.2,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ../figures\fig_pressure_step_fit.pdf

# %% [markdown]
# # Plot diffusivity from pressure-step

# %%
from figure_pressure_step_diffusivities import plot_pressure_step_diffusivities

# Usage
width = text_width * cmToInch
height = 1.3 * base_height * cmToInch

plot_pressure_step_diffusivities(
    file_path='../data/multi-step/stepwise-analysis.xlsx',
    height=height, width=width,
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_pressure_step_diffusivities.pdf.

# %% [markdown]
# # Plot solubility comparison

# %%
from figure_solubility_comparison import plot_solubility_comparison_hdpe

# Usage
width = text_width * cmToInch
height = 2.4 * base_height * cmToInch

plot_solubility_comparison_hdpe(
    data_path='../data/solubility-comparison-HDPE.xlsx',
    width=width, height=height,
    y_lo=0.02, y_up=0.14, x_lo=0.0, 
    display_fig=True,
    save_fig=True,
)
# Out:
# Plot successfully exported to ..\figures\fig_solubility_comparison.pdf.

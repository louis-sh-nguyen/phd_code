# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import os
import sys
import time

# %%
# figure style
plt.style.use('seaborn-v0_8-colorblind')
plt.style.use('../../../../thesis.mplstyle')

# Figure sizes
cmToInch = 1/2.54
text_width = 14.2  # cm
base_height = 5.  # cm
dpi = 400
format = 'pdf'

# %%
# Colour reference
colour = plt.rcParams['axes.prop_cycle'].by_key()['color']

fig, ax = plt.subplots(figsize=(5, 4))  # Adjust figure size as needed
for i, c in enumerate(colour):
    ax.bar(i, 1, color=c)

ax.set_xticks(range(len(colour)))
ax.set_xticklabels([f'C{i}' for i in range(len(colour))])  # Optional: Label the bars
ax.set_yticks([])  # Hide y-axis ticks

plt.show()

# %% [markdown]
# # Figure 2: Lit data at 35 C

# %%
from figure_lit_data_35C import plot_lit_data_35C

width = text_width * cmToInch
height = 2.2 * base_height * cmToInch

plot_lit_data_35C(
    width=width, height=height,
    display_fig=True, save_fig=True
)
# Out:
# Figure saved to ..\figures\fig_lit_data_35C.pdf

# %% [markdown]
# # Figure 3: Lit data at 100 C

# %%
from figure_lit_data_100C import plot_lit_data_100C

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_lit_data_100C(
    width=width, height=height,
    display_fig=True, save_fig=True
)
# Out:
# Figure saved to ..\figures\fig_lit_data_100C.pdf

# %% [markdown]
# # Figure 4: Pure polymer density from default SAFT parameters

# %%
from figure_pure_pol_density import plot_pure_pol_density_default_params

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_pure_pol_density_default_params(
    data_folder_path='../data/PVT-data', 
    width=width, height=height,
    display_fig=True,
    save_fig=True,
    )
# Out:
# Plot saved: ..\figures\fig_pure_pol_density_default_params.pdf

# %% [markdown]
# # Figure 5: Solubility from default SAFT parameters

# %%
from figure_solubility_fitting_data import plot_solubility_fitting_data_default_params

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_solubility_fitting_data_default_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_fitting_data_default_params.pdf

# %% [markdown]
# # Figure 6: Pure polymer density from fitted SAFT parameters

# %%
from figure_pure_pol_density import plot_pure_pol_density_fitted_params

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_pure_pol_density_fitted_params(
    data_folder_path='../data/PVT-data', 
    width=width, height=height,
    display_fig=True,
    save_fig=True,
    )
# Out:
# Plot saved: ..\figures\fig_pure_pol_density_fitted_params.pdf

# %% [markdown]
# # Figure 7: Solubility from fitted SAFT parameters

# %%
from figure_solubility_fitting_data import plot_solubility_fitting_data_fitted_params

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_solubility_fitting_data_fitted_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_fitting_data_fitted_params.pdf

# %% [markdown]
# # Figure 8: Validation of solubility from fitted SAFT parameters

# %%
from figure_solubility_validation_data import plot_solubility_validation_data_fitted_params

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_solubility_validation_data_fitted_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_validation_data_fitted_params.pdf

# %% [markdown]
# # Figure 9: Solubility and polymer partial density in PS at 35, 51, and 81 C

# %%
from figure_solubility_partial_density_35_51_81C import plot_solubility_partial_density_PS_35_51_81C_fitted_params

# Usage
width = text_width * cmToInch
height = 3.05 * base_height * cmToInch

plot_solubility_partial_density_PS_35_51_81C_fitted_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_PS_35-51-81C_fitted_params.pdf

# %% [markdown]
# # Figure 10: Solubility and polymer partial density in PMMA at 35, 51, and 81 C

# %%
from figure_solubility_partial_density_35_51_81C import plot_solubility_partial_density_PMMA_35_51_81C_fitted_params

# Usage
width = text_width * cmToInch
height = 3.05 * base_height * cmToInch

plot_solubility_partial_density_PMMA_35_51_81C_fitted_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_PMMA_35-51-81C_fitted_params.pdf

# %% [markdown]
# # Figure 11: Zoomed-in solubility in PS and PMMA at 35, 51, and 81 C

# %%
from figure_solubility_zoomed_35_51_81C import plot_solubility_zoomed_35_51_81C_fitted_params

# Usage
width = text_width * cmToInch
height = 1.8 * base_height * cmToInch

plot_solubility_zoomed_35_51_81C_fitted_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_zoomed_35-51-81C_fitted_params.pdf

# %% [markdown]
# # Figure 12: Plot CO2 density isotherms

# %%
from figure_CO2_comparison import plot_CO2_density_isotherms

# Usage
width = 0.7 * text_width * cmToInch
height = 1.4 * base_height * cmToInch

plot_CO2_density_isotherms(
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_CO2_density_comparison.pdf

# %% [markdown]
# # Figure: Fugacity coefficients

# %%
from figure_CO2_comparison import plot_CO2_fugacityCoeff_isotherms

# Usage
width = 0.7 * text_width * cmToInch
height = 1.4 * base_height * cmToInch

plot_CO2_fugacityCoeff_isotherms(
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_CO2_fugacityCoeff_comparison.pdf

# %% [markdown]
# # Figure: MW sensitivity

# %%
from figure_solubility_sensitivity import plot_solubility_noRepeatUnits_sensitivity

# Usage
width = text_width * cmToInch
height = 1.15 * base_height * cmToInch

plot_solubility_noRepeatUnits_sensitivity(
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_noRepeatUnits_sensitivity_fitted_params.pdf

# %% [markdown]
# # Figure: Tait fit

# %%
from figure_Tait_fit import plot_Tait_fit

# Usage
width = text_width * cmToInch
height = 2.2 * base_height * cmToInch

plot_Tait_fit(
    width=width, height=height,
    display_fig=True, save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_Tait_fit.pdf

# %% [markdown]
# # Figure: Solubility and polymer partial density in PS at 35, 51, and 81 C (default parameters)

# %%
from figure_solubility_partial_density_35_51_81C import plot_solubility_partial_density_PS_35_51_81C_default_params

# Usage
width = text_width * cmToInch
height = 3.05 * base_height * cmToInch

plot_solubility_partial_density_PS_35_51_81C_default_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_PS_35-51-81C_default_params.pdf

# %% [markdown]
# # Figure: Solubility and polymer partial density in PMMA at 35, 51, and 81 C (default parameters)

# %%
from figure_solubility_partial_density_35_51_81C import plot_solubility_partial_density_PMMA_35_51_81C_default_params

# Usage
width = text_width * cmToInch
height = 3.05 * base_height * cmToInch

plot_solubility_partial_density_PMMA_35_51_81C_default_params(
    width=width, height=height,
    display_fig=True,
    save_fig=True,
)
# Out:
# Figure saved to ..\figures\fig_solubility_PMMA_35-51-81C_default_params.pdf
